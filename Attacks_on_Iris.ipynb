# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.neural_network import MLPClassifier
from tqdm import tqdm
from sklearn.utils import shuffle
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
# Out:
# /Users/jskaf/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
iris = load_iris()
data = np.hstack((iris['data'],[[f'Gerard {i + 1}'] for i in range(len(iris['data']))]))
y_true = iris['target']
data
# Out:
# array([['5.1', '3.5', '1.4', '0.2', 'Gerard 1'],
#        ['4.9', '3.0', '1.4', '0.2', 'Gerard 2'],
#        ['4.7', '3.2', '1.3', '0.2', 'Gerard 3'],
#        ['4.6', '3.1', '1.5', '0.2', 'Gerard 4'],
#        ['5.0', '3.6', '1.4', '0.2', 'Gerard 5'],
#        ['5.4', '3.9', '1.7', '0.4', 'Gerard 6'],
#        ['4.6', '3.4', '1.4', '0.3', 'Gerard 7'],
#        ['5.0', '3.4', '1.5', '0.2', 'Gerard 8'],
#        ['4.4', '2.9', '1.4', '0.2', 'Gerard 9'],
#        ['4.9', '3.1', '1.5', '0.1', 'Gerard 10'],
#        ['5.4', '3.7', '1.5', '0.2', 'Gerard 11'],
#        ['4.8', '3.4', '1.6', '0.2', 'Gerard 12'],
#        ['4.8', '3.0', '1.4', '0.1', 'Gerard 13'],
#        ['4.3', '3.0', '1.1', '0.1', 'Gerard 14'],
#        ['5.8', '4.0', '1.2', '0.2', 'Gerard 15'],
#        ['5.7', '4.4', '1.5', '0.4', 'Gerard 16'],
#        ['5.4', '3.9', '1.3', '0.4', 'Gerard 17'],
#        ['5.1', '3.5', '1.4', '0.3', 'Gerard 18'],
#        ['5.7', '3.8', '1.7', '0.3', 'Gerard 19'],
#        ['5.1', '3.8', '1.5', '0.3', 'Gerard 20'],
#        ['5.4', '3.4', '1.7', '0.2', 'Gerard 21'],
#        ['5.1', '3.7', '1.5', '0.4', 'Gerard 22'],
#        ['4.6', '3.6', '1.0', '0.2', 'Gerard 23'],
#        ['5.1', '3.3', '1.7', '0.5', 'Gerard 24'],
#        ['4.8', '3.4', '1.9', '0.2', 'Gerard 25'],
#        ['5.0', '3.0', '1.6', '0.2', 'Gerard 26'],
#        ['5.0', '3.4', '1.6', '0.4', 'Gerard 27'],
#        ['5.2', '3.5', '1.5', '0.2', 'Gerard 28'],
#        ['5.2', '3.4', '1.4', '0.2', 'Gerard 29'],
#        ['4.7', '3.2', '1.6', '0.2', 'Gerard 30'],
#        ['4.8', '3.1', '1.6', '0.2', 'Gerard 31'],
#        ['5.4', '3.4', '1.5', '0.4', 'Gerard 32'],
#        ['5.2', '4.1', '1.5', '0.1', 'Gerard 33'],
#        ['5.5', '4.2', '1.4', '0.2', 'Gerard 34'],
#        ['4.9', '3.1', '1.5', '0.2', 'Gerard 35'],
#        ['5.0', '3.2', '1.2', '0.2', 'Gerard 36'],
#        ['5.5', '3.5', '1.3', '0.2', 'Gerard 37'],
#        ['4.9', '3.6', '1.4', '0.1', 'Gerard 38'],
#        ['4.4', '3.0', '1.3', '0.2', 'Gerard 39'],
#        ['5.1', '3.4', '1.5', '0.2', 'Gerard 40'],
#        ['5.0', '3.5', '1.3', '0.3', 'Gerard 41'],
#        ['4.5', '2.3', '1.3', '0.3', 'Gerard 42'],
#        ['4.4', '3.2', '1.3', '0.2', 'Gerard 43'],
#        ['5.0', '3.5', '1.6', '0.6', 'Gerard 44'],
#        ['5.1', '3.8', '1.9', '0.4', 'Gerard 45'],
#        ['4.8', '3.0', '1.4', '0.3', 'Gerard 46'],
#        ['5.1', '3.8', '1.6', '0.2', 'Gerard 47'],
#        ['4.6', '3.2', '1.4', '0.2', 'Gerard 48'],
#        ['5.3', '3.7', '1.5', '0.2', 'Gerard 49'],
#        ['5.0', '3.3', '1.4', '0.2', 'Gerard 50'],
#        ['7.0', '3.2', '4.7', '1.4', 'Gerard 51'],
#        ['6.4', '3.2', '4.5', '1.5', 'Gerard 52'],
#        ['6.9', '3.1', '4.9', '1.5', 'Gerard 53'],
#        ['5.5', '2.3', '4.0', '1.3', 'Gerard 54'],
#        ['6.5', '2.8', '4.6', '1.5', 'Gerard 55'],
#        ['5.7', '2.8', '4.5', '1.3', 'Gerard 56'],
#        ['6.3', '3.3', '4.7', '1.6', 'Gerard 57'],
#        ['4.9', '2.4', '3.3', '1.0', 'Gerard 58'],
#        ['6.6', '2.9', '4.6', '1.3', 'Gerard 59'],
#        ['5.2', '2.7', '3.9', '1.4', 'Gerard 60'],
#        ['5.0', '2.0', '3.5', '1.0', 'Gerard 61'],
#        ['5.9', '3.0', '4.2', '1.5', 'Gerard 62'],
#        ['6.0', '2.2', '4.0', '1.0', 'Gerard 63'],
#        ['6.1', '2.9', '4.7', '1.4', 'Gerard 64'],
#        ['5.6', '2.9', '3.6', '1.3', 'Gerard 65'],
#        ['6.7', '3.1', '4.4', '1.4', 'Gerard 66'],
#        ['5.6', '3.0', '4.5', '1.5', 'Gerard 67'],
#        ['5.8', '2.7', '4.1', '1.0', 'Gerard 68'],
#        ['6.2', '2.2', '4.5', '1.5', 'Gerard 69'],
#        ['5.6', '2.5', '3.9', '1.1', 'Gerard 70'],
#        ['5.9', '3.2', '4.8', '1.8', 'Gerard 71'],
#        ['6.1', '2.8', '4.0', '1.3', 'Gerard 72'],
#        ['6.3', '2.5', '4.9', '1.5', 'Gerard 73'],
#        ['6.1', '2.8', '4.7', '1.2', 'Gerard 74'],
#        ['6.4', '2.9', '4.3', '1.3', 'Gerard 75'],
#        ['6.6', '3.0', '4.4', '1.4', 'Gerard 76'],
#        ['6.8', '2.8', '4.8', '1.4', 'Gerard 77'],
#        ['6.7', '3.0', '5.0', '1.7', 'Gerard 78'],
#        ['6.0', '2.9', '4.5', '1.5', 'Gerard 79'],
#        ['5.7', '2.6', '3.5', '1.0', 'Gerard 80'],
#        ['5.5', '2.4', '3.8', '1.1', 'Gerard 81'],
#        ['5.5', '2.4', '3.7', '1.0', 'Gerard 82'],
#        ['5.8', '2.7', '3.9', '1.2', 'Gerard 83'],
#        ['6.0', '2.7', '5.1', '1.6', 'Gerard 84'],
#        ['5.4', '3.0', '4.5', '1.5', 'Gerard 85'],
#        ['6.0', '3.4', '4.5', '1.6', 'Gerard 86'],
#        ['6.7', '3.1', '4.7', '1.5', 'Gerard 87'],
#        ['6.3', '2.3', '4.4', '1.3', 'Gerard 88'],
#        ['5.6', '3.0', '4.1', '1.3', 'Gerard 89'],
#        ['5.5', '2.5', '4.0', '1.3', 'Gerard 90'],
#        ['5.5', '2.6', '4.4', '1.2', 'Gerard 91'],
#        ['6.1', '3.0', '4.6', '1.4', 'Gerard 92'],
#        ['5.8', '2.6', '4.0', '1.2', 'Gerard 93'],
#        ['5.0', '2.3', '3.3', '1.0', 'Gerard 94'],
#        ['5.6', '2.7', '4.2', '1.3', 'Gerard 95'],
#        ['5.7', '3.0', '4.2', '1.2', 'Gerard 96'],
#        ['5.7', '2.9', '4.2', '1.3', 'Gerard 97'],
#        ['6.2', '2.9', '4.3', '1.3', 'Gerard 98'],
#        ['5.1', '2.5', '3.0', '1.1', 'Gerard 99'],
#        ['5.7', '2.8', '4.1', '1.3', 'Gerard 100'],
#        ['6.3', '3.3', '6.0', '2.5', 'Gerard 101'],
#        ['5.8', '2.7', '5.1', '1.9', 'Gerard 102'],
#        ['7.1', '3.0', '5.9', '2.1', 'Gerard 103'],
#        ['6.3', '2.9', '5.6', '1.8', 'Gerard 104'],
#        ['6.5', '3.0', '5.8', '2.2', 'Gerard 105'],
#        ['7.6', '3.0', '6.6', '2.1', 'Gerard 106'],
#        ['4.9', '2.5', '4.5', '1.7', 'Gerard 107'],
#        ['7.3', '2.9', '6.3', '1.8', 'Gerard 108'],
#        ['6.7', '2.5', '5.8', '1.8', 'Gerard 109'],
#        ['7.2', '3.6', '6.1', '2.5', 'Gerard 110'],
#        ['6.5', '3.2', '5.1', '2.0', 'Gerard 111'],
#        ['6.4', '2.7', '5.3', '1.9', 'Gerard 112'],
#        ['6.8', '3.0', '5.5', '2.1', 'Gerard 113'],
#        ['5.7', '2.5', '5.0', '2.0', 'Gerard 114'],
#        ['5.8', '2.8', '5.1', '2.4', 'Gerard 115'],
#        ['6.4', '3.2', '5.3', '2.3', 'Gerard 116'],
#        ['6.5', '3.0', '5.5', '1.8', 'Gerard 117'],
#        ['7.7', '3.8', '6.7', '2.2', 'Gerard 118'],
#        ['7.7', '2.6', '6.9', '2.3', 'Gerard 119'],
#        ['6.0', '2.2', '5.0', '1.5', 'Gerard 120'],
#        ['6.9', '3.2', '5.7', '2.3', 'Gerard 121'],
#        ['5.6', '2.8', '4.9', '2.0', 'Gerard 122'],
#        ['7.7', '2.8', '6.7', '2.0', 'Gerard 123'],
#        ['6.3', '2.7', '4.9', '1.8', 'Gerard 124'],
#        ['6.7', '3.3', '5.7', '2.1', 'Gerard 125'],
#        ['7.2', '3.2', '6.0', '1.8', 'Gerard 126'],
#        ['6.2', '2.8', '4.8', '1.8', 'Gerard 127'],
#        ['6.1', '3.0', '4.9', '1.8', 'Gerard 128'],
#        ['6.4', '2.8', '5.6', '2.1', 'Gerard 129'],
#        ['7.2', '3.0', '5.8', '1.6', 'Gerard 130'],
#        ['7.4', '2.8', '6.1', '1.9', 'Gerard 131'],
#        ['7.9', '3.8', '6.4', '2.0', 'Gerard 132'],
#        ['6.4', '2.8', '5.6', '2.2', 'Gerard 133'],
#        ['6.3', '2.8', '5.1', '1.5', 'Gerard 134'],
#        ['6.1', '2.6', '5.6', '1.4', 'Gerard 135'],
#        ['7.7', '3.0', '6.1', '2.3', 'Gerard 136'],
#        ['6.3', '3.4', '5.6', '2.4', 'Gerard 137'],
#        ['6.4', '3.1', '5.5', '1.8', 'Gerard 138'],
#        ['6.0', '3.0', '4.8', '1.8', 'Gerard 139'],
#        ['6.9', '3.1', '5.4', '2.1', 'Gerard 140'],
#        ['6.7', '3.1', '5.6', '2.4', 'Gerard 141'],
#        ['6.9', '3.1', '5.1', '2.3', 'Gerard 142'],
#        ['5.8', '2.7', '5.1', '1.9', 'Gerard 143'],
#        ['6.8', '3.2', '5.9', '2.3', 'Gerard 144'],
#        ['6.7', '3.3', '5.7', '2.5', 'Gerard 145'],
#        ['6.7', '3.0', '5.2', '2.3', 'Gerard 146'],
#        ['6.3', '2.5', '5.0', '1.9', 'Gerard 147'],
#        ['6.5', '3.0', '5.2', '2.0', 'Gerard 148'],
#        ['6.2', '3.4', '5.4', '2.3', 'Gerard 149'],
#        ['5.9', '3.0', '5.1', '1.8', 'Gerard 150']], dtype='<U32')

# %%
df = pd.DataFrame(data= np.c_[iris['data'], iris['target']],
                     columns= iris['feature_names'] + ['target'], 
                     index=[f'Gerard {i + 1}' for i in range(len(data))])
df
# Out:
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# Gerard 1                  5.1               3.5                1.4
# Gerard 2                  4.9               3.0                1.4
# Gerard 3                  4.7               3.2                1.3
# Gerard 4                  4.6               3.1                1.5
# Gerard 5                  5.0               3.6                1.4
# ...                       ...               ...                ...
# Gerard 146                6.7               3.0                5.2
# Gerard 147                6.3               2.5                5.0
# Gerard 148                6.5               3.0                5.2
# Gerard 149                6.2               3.4                5.4
# Gerard 150                5.9               3.0                5.1
#
#             petal width (cm)  target
# Gerard 1                 0.2     0.0
# Gerard 2                 0.2     0.0
# Gerard 3                 0.2     0.0
# Gerard 4                 0.2     0.0
# Gerard 5                 0.2     0.0
# ...                      ...     ...
# Gerard 146               2.3     2.0
# Gerard 147               1.9     2.0
# Gerard 148               2.0     2.0
# Gerard 149               2.3     2.0
# Gerard 150               1.8     2.0
#
# [150 rows x 5 columns]

# %%
columns_mins = df.min(axis=0).to_numpy()
columns_maxs = df.max(axis=0).to_numpy()
columns_mins
# Out:
# array([4.3, 2. , 1. , 0.1, 0. ])

# %%
train_dataset_target_model, test_dataset_target_model, train_dataset_target_model_labels, test_dataset_target_model_labels = train_test_split(data, y_true, test_size=0.2)
train = train_dataset_target_model[:,0:4]
test = test_dataset_target_model[:,0:4]

# %%
test_dataset_target_model
# Out:
# array([['5.6', '2.7', '4.2', '1.3', 'Gerard 95'],
#        ['6.5', '3.0', '5.2', '2.0', 'Gerard 148'],
#        ['6.7', '3.1', '5.6', '2.4', 'Gerard 141'],
#        ['5.4', '3.4', '1.5', '0.4', 'Gerard 32'],
#        ['7.2', '3.6', '6.1', '2.5', 'Gerard 110'],
#        ['6.7', '3.0', '5.2', '2.3', 'Gerard 146'],
#        ['6.8', '2.8', '4.8', '1.4', 'Gerard 77'],
#        ['6.0', '2.2', '4.0', '1.0', 'Gerard 63'],
#        ['7.7', '3.0', '6.1', '2.3', 'Gerard 136'],
#        ['6.1', '3.0', '4.9', '1.8', 'Gerard 128'],
#        ['4.9', '3.0', '1.4', '0.2', 'Gerard 2'],
#        ['5.6', '3.0', '4.1', '1.3', 'Gerard 89'],
#        ['5.9', '3.0', '4.2', '1.5', 'Gerard 62'],
#        ['5.1', '3.3', '1.7', '0.5', 'Gerard 24'],
#        ['5.0', '2.0', '3.5', '1.0', 'Gerard 61'],
#        ['7.7', '2.8', '6.7', '2.0', 'Gerard 123'],
#        ['6.7', '2.5', '5.8', '1.8', 'Gerard 109'],
#        ['5.6', '2.9', '3.6', '1.3', 'Gerard 65'],
#        ['5.6', '2.5', '3.9', '1.1', 'Gerard 70'],
#        ['4.4', '3.0', '1.3', '0.2', 'Gerard 39'],
#        ['5.4', '3.4', '1.7', '0.2', 'Gerard 21'],
#        ['6.3', '2.5', '4.9', '1.5', 'Gerard 73'],
#        ['6.1', '2.6', '5.6', '1.4', 'Gerard 135'],
#        ['6.7', '3.1', '4.7', '1.5', 'Gerard 87'],
#        ['5.0', '3.5', '1.6', '0.6', 'Gerard 44'],
#        ['6.3', '2.5', '5.0', '1.9', 'Gerard 147'],
#        ['6.7', '3.3', '5.7', '2.5', 'Gerard 145'],
#        ['5.9', '3.2', '4.8', '1.8', 'Gerard 71'],
#        ['6.4', '2.8', '5.6', '2.1', 'Gerard 129'],
#        ['7.1', '3.0', '5.9', '2.1', 'Gerard 103']], dtype='<U32')

# %%
target_model = MLPClassifier(hidden_layer_sizes=(20,10), max_iter=1000, verbose=True).fit(train, train_dataset_target_model_labels)
target_model.score(test, test_dataset_target_model_labels)
# Out:
# Iteration 1, loss = 2.20710219
# Iteration 2, loss = 2.16118318
# Iteration 3, loss = 2.11814430
# Iteration 4, loss = 2.07679312
# Iteration 5, loss = 2.03675107
# Iteration 6, loss = 1.99819669
# Iteration 7, loss = 1.96112857
# Iteration 8, loss = 1.92696352
# Iteration 9, loss = 1.89417594
# Iteration 10, loss = 1.86244077
# Iteration 11, loss = 1.83160983
# Iteration 12, loss = 1.80182057
# Iteration 13, loss = 1.77290624
# Iteration 14, loss = 1.74498113
# Iteration 15, loss = 1.71802881
# Iteration 16, loss = 1.69199831
# Iteration 17, loss = 1.66682644
# Iteration 18, loss = 1.64251543
# Iteration 19, loss = 1.61905393
# Iteration 20, loss = 1.59642593
# Iteration 21, loss = 1.57470738
# Iteration 22, loss = 1.55373030
# Iteration 23, loss = 1.53370703
# Iteration 24, loss = 1.51448872
# Iteration 25, loss = 1.49628305
# Iteration 26, loss = 1.47900578
# Iteration 27, loss = 1.46273158
# Iteration 28, loss = 1.44771298
# Iteration 29, loss = 1.43385781
# Iteration 30, loss = 1.42126544
# Iteration 31, loss = 1.41021017
# Iteration 32, loss = 1.40013003
# Iteration 33, loss = 1.39081663
# Iteration 34, loss = 1.38228648
# Iteration 35, loss = 1.37426250
# Iteration 36, loss = 1.36675725
# Iteration 37, loss = 1.35951053
# Iteration 38, loss = 1.35240414
# Iteration 39, loss = 1.34520406
# Iteration 40, loss = 1.33775567
# Iteration 41, loss = 1.32997478
# Iteration 42, loss = 1.32163103
# Iteration 43, loss = 1.31278309
# Iteration 44, loss = 1.30358638
# Iteration 45, loss = 1.29404942
# Iteration 46, loss = 1.28420164
# Iteration 47, loss = 1.27395191
# Iteration 48, loss = 1.26334992
# Iteration 49, loss = 1.25249152
# Iteration 50, loss = 1.24143471
# Iteration 51, loss = 1.23020063
# Iteration 52, loss = 1.21881398
# Iteration 53, loss = 1.20728781
# Iteration 54, loss = 1.19563918
# Iteration 55, loss = 1.18391446
# Iteration 56, loss = 1.17220393
# Iteration 57, loss = 1.16045715
# Iteration 58, loss = 1.14863594
# Iteration 59, loss = 1.13683887
# Iteration 60, loss = 1.12504487
# Iteration 61, loss = 1.11361305
# Iteration 62, loss = 1.10233528
# Iteration 63, loss = 1.09180577
# Iteration 64, loss = 1.08337308
# Iteration 65, loss = 1.07812403
# Iteration 66, loss = 1.07413725
# Iteration 67, loss = 1.07063143
# Iteration 68, loss = 1.06745021
# Iteration 69, loss = 1.06424911
# Iteration 70, loss = 1.06106588
# Iteration 71, loss = 1.05788106
# Iteration 72, loss = 1.05472477
# Iteration 73, loss = 1.05159767
# Iteration 74, loss = 1.04855709
# Iteration 75, loss = 1.04565457
# Iteration 76, loss = 1.04284450
# Iteration 77, loss = 1.04011841
# Iteration 78, loss = 1.03746760
# Iteration 79, loss = 1.03482722
# Iteration 80, loss = 1.03226015
# Iteration 81, loss = 1.02973093
# Iteration 82, loss = 1.02719126
# Iteration 83, loss = 1.02461178
# Iteration 84, loss = 1.02199671
# Iteration 85, loss = 1.01936622
# Iteration 86, loss = 1.01668827
# Iteration 87, loss = 1.01396263
# Iteration 88, loss = 1.01119173
# Iteration 89, loss = 1.00837795
# Iteration 90, loss = 1.00552360
# Iteration 91, loss = 1.00263147
# Iteration 92, loss = 0.99970428
# Iteration 93, loss = 0.99676771
# Iteration 94, loss = 0.99379888
# Iteration 95, loss = 0.99079193
# Iteration 96, loss = 0.98775590
# Iteration 97, loss = 0.98469143
# Iteration 98, loss = 0.98159927
# Iteration 99, loss = 0.97848000
# Iteration 100, loss = 0.97533410
# Iteration 101, loss = 0.97216192
# Iteration 102, loss = 0.96896372
# Iteration 103, loss = 0.96573966
# Iteration 104, loss = 0.96248987
# Iteration 105, loss = 0.95921439
# Iteration 106, loss = 0.95591324
# Iteration 107, loss = 0.95258483
# Iteration 108, loss = 0.94922844
# Iteration 109, loss = 0.94584481
# Iteration 110, loss = 0.94243585
# Iteration 111, loss = 0.93900486
# Iteration 112, loss = 0.93555451
# Iteration 113, loss = 0.93207591
# Iteration 114, loss = 0.92857115
# Iteration 115, loss = 0.92504234
# Iteration 116, loss = 0.92149399
# Iteration 117, loss = 0.91792195
# Iteration 118, loss = 0.91433011
# Iteration 119, loss = 0.91071371
# Iteration 120, loss = 0.90707466
# Iteration 121, loss = 0.90342085
# Iteration 122, loss = 0.89974222
# Iteration 123, loss = 0.89604123
# Iteration 124, loss = 0.89232276
# Iteration 125, loss = 0.88859332
# Iteration 126, loss = 0.88484594
# Iteration 127, loss = 0.88108264
# Iteration 128, loss = 0.87730361
# Iteration 129, loss = 0.87351561
# Iteration 130, loss = 0.86972307
# Iteration 131, loss = 0.86593010
# Iteration 132, loss = 0.86213995
# Iteration 133, loss = 0.85836110
# Iteration 134, loss = 0.85459406
# Iteration 135, loss = 0.85085893
# Iteration 136, loss = 0.84712485
# Iteration 137, loss = 0.84338834
# Iteration 138, loss = 0.83965067
# Iteration 139, loss = 0.83590687
# Iteration 140, loss = 0.83217279
# Iteration 141, loss = 0.82845950
# Iteration 142, loss = 0.82476399
# Iteration 143, loss = 0.82109187
# Iteration 144, loss = 0.81741590
# Iteration 145, loss = 0.81377219
# Iteration 146, loss = 0.81012239
# Iteration 147, loss = 0.80646705
# Iteration 148, loss = 0.80281109
# Iteration 149, loss = 0.79915801
# Iteration 150, loss = 0.79551141
# Iteration 151, loss = 0.79187161
# Iteration 152, loss = 0.78824080
# Iteration 153, loss = 0.78462095
# Iteration 154, loss = 0.78101573
# Iteration 155, loss = 0.77742526
# Iteration 156, loss = 0.77384790
# Iteration 157, loss = 0.77028482
# Iteration 158, loss = 0.76673683
# Iteration 159, loss = 0.76320420
# Iteration 160, loss = 0.75968606
# Iteration 161, loss = 0.75618484
# Iteration 162, loss = 0.75269861
# Iteration 163, loss = 0.74922463
# Iteration 164, loss = 0.74576597
# Iteration 165, loss = 0.74232150
# Iteration 166, loss = 0.73888964
# Iteration 167, loss = 0.73547256
# Iteration 168, loss = 0.73207567
# Iteration 169, loss = 0.72869217
# Iteration 170, loss = 0.72532030
# Iteration 171, loss = 0.72194936
# Iteration 172, loss = 0.71857214
# Iteration 173, loss = 0.71517691
# Iteration 174, loss = 0.71176494
# Iteration 175, loss = 0.70831371
# Iteration 176, loss = 0.70483155
# Iteration 177, loss = 0.70132046
# Iteration 178, loss = 0.69777395
# Iteration 179, loss = 0.69418215
# Iteration 180, loss = 0.69058052
# Iteration 181, loss = 0.68699822
# Iteration 182, loss = 0.68350187
# Iteration 183, loss = 0.68029010
# Iteration 184, loss = 0.67679581
# Iteration 185, loss = 0.67316039
# Iteration 186, loss = 0.66959706
# Iteration 187, loss = 0.66616087
# Iteration 188, loss = 0.66278942
# Iteration 189, loss = 0.65943758
# Iteration 190, loss = 0.65605984
# Iteration 191, loss = 0.65267173
# Iteration 192, loss = 0.64928006
# Iteration 193, loss = 0.64590184
# Iteration 194, loss = 0.64256647
# Iteration 195, loss = 0.63929466
# Iteration 196, loss = 0.63606579
# Iteration 197, loss = 0.63284879
# Iteration 198, loss = 0.62962213
# Iteration 199, loss = 0.62640482
# Iteration 200, loss = 0.62322232
# Iteration 201, loss = 0.62006848
# Iteration 202, loss = 0.61694313
# Iteration 203, loss = 0.61385724
# Iteration 204, loss = 0.61081836
# Iteration 205, loss = 0.60780519
# Iteration 206, loss = 0.60481303
# Iteration 207, loss = 0.60187330
# Iteration 208, loss = 0.59897161
# Iteration 209, loss = 0.59610906
# Iteration 210, loss = 0.59328396
# Iteration 211, loss = 0.59050374
# Iteration 212, loss = 0.58775678
# Iteration 213, loss = 0.58503967
# Iteration 214, loss = 0.58235731
# Iteration 215, loss = 0.57970937
# Iteration 216, loss = 0.57709446
# Iteration 217, loss = 0.57451405
# Iteration 218, loss = 0.57197023
# Iteration 219, loss = 0.56946031
# Iteration 220, loss = 0.56698528
# Iteration 221, loss = 0.56454476
# Iteration 222, loss = 0.56213635
# Iteration 223, loss = 0.55976346
# Iteration 224, loss = 0.55742236
# Iteration 225, loss = 0.55512171
# Iteration 226, loss = 0.55285381
# Iteration 227, loss = 0.55062528
# Iteration 228, loss = 0.54843127
# Iteration 229, loss = 0.54627142
# Iteration 230, loss = 0.54414272
# Iteration 231, loss = 0.54204912
# Iteration 232, loss = 0.53998579
# Iteration 233, loss = 0.53795617
# Iteration 234, loss = 0.53596341
# Iteration 235, loss = 0.53400247
# Iteration 236, loss = 0.53207255
# Iteration 237, loss = 0.53017905
# Iteration 238, loss = 0.52831524
# Iteration 239, loss = 0.52648033
# Iteration 240, loss = 0.52467302
# Iteration 241, loss = 0.52289694
# Iteration 242, loss = 0.52114677
# Iteration 243, loss = 0.51942229
# Iteration 244, loss = 0.51772364
# Iteration 245, loss = 0.51604855
# Iteration 246, loss = 0.51439629
# Iteration 247, loss = 0.51276963
# Iteration 248, loss = 0.51116647
# Iteration 249, loss = 0.50958592
# Iteration 250, loss = 0.50803671
# Iteration 251, loss = 0.50650827
# Iteration 252, loss = 0.50499976
# Iteration 253, loss = 0.50350968
# Iteration 254, loss = 0.50203961
# Iteration 255, loss = 0.50058959
# Iteration 256, loss = 0.49916219
# Iteration 257, loss = 0.49775338
# Iteration 258, loss = 0.49636133
# Iteration 259, loss = 0.49498529
# Iteration 260, loss = 0.49362759
# Iteration 261, loss = 0.49228696
# Iteration 262, loss = 0.49096404
# Iteration 263, loss = 0.48965517
# Iteration 264, loss = 0.48836047
# Iteration 265, loss = 0.48708414
# Iteration 266, loss = 0.48582167
# Iteration 267, loss = 0.48457212
# Iteration 268, loss = 0.48333513
# Iteration 269, loss = 0.48211059
# Iteration 270, loss = 0.48090152
# Iteration 271, loss = 0.47970527
# Iteration 272, loss = 0.47852109
# Iteration 273, loss = 0.47734823
# Iteration 274, loss = 0.47618651
# Iteration 275, loss = 0.47503569
# Iteration 276, loss = 0.47389724
# Iteration 277, loss = 0.47276981
# Iteration 278, loss = 0.47165225
# Iteration 279, loss = 0.47054490
# Iteration 280, loss = 0.46944636
# Iteration 281, loss = 0.46835714
# Iteration 282, loss = 0.46727798
# Iteration 283, loss = 0.46620793
# Iteration 284, loss = 0.46514849
# Iteration 285, loss = 0.46409240
# Iteration 286, loss = 0.46304661
# Iteration 287, loss = 0.46200814
# Iteration 288, loss = 0.46097631
# Iteration 289, loss = 0.45995076
# Iteration 290, loss = 0.45893147
# Iteration 291, loss = 0.45791740
# Iteration 292, loss = 0.45691111
# Iteration 293, loss = 0.45591027
# Iteration 294, loss = 0.45491402
# Iteration 295, loss = 0.45392215
# Iteration 296, loss = 0.45293477
# Iteration 297, loss = 0.45195195
# Iteration 298, loss = 0.45097570
# Iteration 299, loss = 0.45001101
# Iteration 300, loss = 0.44905219
# Iteration 301, loss = 0.44809896
# Iteration 302, loss = 0.44714372
# Iteration 303, loss = 0.44619611
# Iteration 304, loss = 0.44525215
# Iteration 305, loss = 0.44431210
# Iteration 306, loss = 0.44337697
# Iteration 307, loss = 0.44244514
# Iteration 308, loss = 0.44151654
# Iteration 309, loss = 0.44059108
# Iteration 310, loss = 0.43966867
# Iteration 311, loss = 0.43874919
# Iteration 312, loss = 0.43783253
# Iteration 313, loss = 0.43691879
# Iteration 314, loss = 0.43600973
# Iteration 315, loss = 0.43510519
# Iteration 316, loss = 0.43420120
# Iteration 317, loss = 0.43329965
# Iteration 318, loss = 0.43240173
# Iteration 319, loss = 0.43150608
# Iteration 320, loss = 0.43061170
# Iteration 321, loss = 0.42971898
# Iteration 322, loss = 0.42882928
# Iteration 323, loss = 0.42794332
# Iteration 324, loss = 0.42705254
# Iteration 325, loss = 0.42616681
# Iteration 326, loss = 0.42528337
# Iteration 327, loss = 0.42440096
# Iteration 328, loss = 0.42351888
# Iteration 329, loss = 0.42263605
# Iteration 330, loss = 0.42175250
# Iteration 331, loss = 0.42087012
# Iteration 332, loss = 0.41998804
# Iteration 333, loss = 0.41910487
# Iteration 334, loss = 0.41822217
# Iteration 335, loss = 0.41733984
# Iteration 336, loss = 0.41645679
# Iteration 337, loss = 0.41557360
# Iteration 338, loss = 0.41469322
# Iteration 339, loss = 0.41381483
# Iteration 340, loss = 0.41293507
# Iteration 341, loss = 0.41206272
# Iteration 342, loss = 0.41119497
# Iteration 343, loss = 0.41032606
# Iteration 344, loss = 0.40945800
# Iteration 345, loss = 0.40859416
# Iteration 346, loss = 0.40772616
# Iteration 347, loss = 0.40686163
# Iteration 348, loss = 0.40599506
# Iteration 349, loss = 0.40512856
# Iteration 350, loss = 0.40426242
# Iteration 351, loss = 0.40339666
# Iteration 352, loss = 0.40253067
# Iteration 353, loss = 0.40166334
# Iteration 354, loss = 0.40079670
# Iteration 355, loss = 0.39992947
# Iteration 356, loss = 0.39906292
# Iteration 357, loss = 0.39819479
# Iteration 358, loss = 0.39732724
# Iteration 359, loss = 0.39645940
# Iteration 360, loss = 0.39559136
# Iteration 361, loss = 0.39472255
# Iteration 362, loss = 0.39385286
# Iteration 363, loss = 0.39298238
# Iteration 364, loss = 0.39211144
# Iteration 365, loss = 0.39124033
# Iteration 366, loss = 0.39036801
# Iteration 367, loss = 0.38949702
# Iteration 368, loss = 0.38862179
# Iteration 369, loss = 0.38774717
# Iteration 370, loss = 0.38687107
# Iteration 371, loss = 0.38599346
# Iteration 372, loss = 0.38511361
# Iteration 373, loss = 0.38423858
# Iteration 374, loss = 0.38336045
# Iteration 375, loss = 0.38248054
# Iteration 376, loss = 0.38160526
# Iteration 377, loss = 0.38073797
# Iteration 378, loss = 0.37987171
# Iteration 379, loss = 0.37900583
# Iteration 380, loss = 0.37814837
# Iteration 381, loss = 0.37729221
# Iteration 382, loss = 0.37643362
# Iteration 383, loss = 0.37557519
# Iteration 384, loss = 0.37471530
# Iteration 385, loss = 0.37385349
# Iteration 386, loss = 0.37299073
# Iteration 387, loss = 0.37213043
# Iteration 388, loss = 0.37127113
# Iteration 389, loss = 0.37041275
# Iteration 390, loss = 0.36955613
# Iteration 391, loss = 0.36870185
# Iteration 392, loss = 0.36784281
# Iteration 393, loss = 0.36698457
# Iteration 394, loss = 0.36612660
# Iteration 395, loss = 0.36527074
# Iteration 396, loss = 0.36441617
# Iteration 397, loss = 0.36356191
# Iteration 398, loss = 0.36270711
# Iteration 399, loss = 0.36185266
# Iteration 400, loss = 0.36099887
# Iteration 401, loss = 0.36014523
# Iteration 402, loss = 0.35929378
# Iteration 403, loss = 0.35844369
# Iteration 404, loss = 0.35759397
# Iteration 405, loss = 0.35674464
# Iteration 406, loss = 0.35589616
# Iteration 407, loss = 0.35504746
# Iteration 408, loss = 0.35419933
# Iteration 409, loss = 0.35335099
# Iteration 410, loss = 0.35249982
# Iteration 411, loss = 0.35164715
# Iteration 412, loss = 0.35079313
# Iteration 413, loss = 0.34994281
# Iteration 414, loss = 0.34909997
# Iteration 415, loss = 0.34825952
# Iteration 416, loss = 0.34741719
# Iteration 417, loss = 0.34657168
# Iteration 418, loss = 0.34572666
# Iteration 419, loss = 0.34488157
# Iteration 420, loss = 0.34403380
# Iteration 421, loss = 0.34318860
# Iteration 422, loss = 0.34234222
# Iteration 423, loss = 0.34149542
# Iteration 424, loss = 0.34065220
# Iteration 425, loss = 0.33981000
# Iteration 426, loss = 0.33896769
# Iteration 427, loss = 0.33812496
# Iteration 428, loss = 0.33728062
# Iteration 429, loss = 0.33643685
# Iteration 430, loss = 0.33559337
# Iteration 431, loss = 0.33474908
# Iteration 432, loss = 0.33390460
# Iteration 433, loss = 0.33306195
# Iteration 434, loss = 0.33221901
# Iteration 435, loss = 0.33137620
# Iteration 436, loss = 0.33053290
# Iteration 437, loss = 0.32968919
# Iteration 438, loss = 0.32884725
# Iteration 439, loss = 0.32800854
# Iteration 440, loss = 0.32716995
# Iteration 441, loss = 0.32633158
# Iteration 442, loss = 0.32549356
# Iteration 443, loss = 0.32465864
# Iteration 444, loss = 0.32382179
# Iteration 445, loss = 0.32298636
# Iteration 446, loss = 0.32215170
# Iteration 447, loss = 0.32131717
# Iteration 448, loss = 0.32048172
# Iteration 449, loss = 0.31964487
# Iteration 450, loss = 0.31880649
# Iteration 451, loss = 0.31796699
# Iteration 452, loss = 0.31712678
# Iteration 453, loss = 0.31628828
# Iteration 454, loss = 0.31544607
# Iteration 455, loss = 0.31460210
# Iteration 456, loss = 0.31375726
# Iteration 457, loss = 0.31291237
# Iteration 458, loss = 0.31206813
# Iteration 459, loss = 0.31122351
# Iteration 460, loss = 0.31037889
# Iteration 461, loss = 0.30953982
# Iteration 462, loss = 0.30870003
# Iteration 463, loss = 0.30786090
# Iteration 464, loss = 0.30701869
# Iteration 465, loss = 0.30617501
# Iteration 466, loss = 0.30533012
# Iteration 467, loss = 0.30448606
# Iteration 468, loss = 0.30364123
# Iteration 469, loss = 0.30279419
# Iteration 470, loss = 0.30194435
# Iteration 471, loss = 0.30109423
# Iteration 472, loss = 0.30024385
# Iteration 473, loss = 0.29939079
# Iteration 474, loss = 0.29853728
# Iteration 475, loss = 0.29767986
# Iteration 476, loss = 0.29682035
# Iteration 477, loss = 0.29595951
# Iteration 478, loss = 0.29509806
# Iteration 479, loss = 0.29423502
# Iteration 480, loss = 0.29336743
# Iteration 481, loss = 0.29249877
# Iteration 482, loss = 0.29162386
# Iteration 483, loss = 0.29074703
# Iteration 484, loss = 0.28986649
# Iteration 485, loss = 0.28897961
# Iteration 486, loss = 0.28808943
# Iteration 487, loss = 0.28723295
# Iteration 488, loss = 0.28630519
# Iteration 489, loss = 0.28543026
# Iteration 490, loss = 0.28455005
# Iteration 491, loss = 0.28366582
# Iteration 492, loss = 0.28277917
# Iteration 493, loss = 0.28188407
# Iteration 494, loss = 0.28098777
# Iteration 495, loss = 0.28008284
# Iteration 496, loss = 0.27917041
# Iteration 497, loss = 0.27825431
# Iteration 498, loss = 0.27735339
# Iteration 499, loss = 0.27646224
# Iteration 500, loss = 0.27556640
# Iteration 501, loss = 0.27466567
# Iteration 502, loss = 0.27376285
# Iteration 503, loss = 0.27284399
# Iteration 504, loss = 0.27191535
# Iteration 505, loss = 0.27098250
# Iteration 506, loss = 0.27003176
# Iteration 507, loss = 0.26906603
# Iteration 508, loss = 0.26812013
# Iteration 509, loss = 0.26719723
# Iteration 510, loss = 0.26629442
# Iteration 511, loss = 0.26539314
# Iteration 512, loss = 0.26448363
# Iteration 513, loss = 0.26357521
# Iteration 514, loss = 0.26266577
# Iteration 515, loss = 0.26176566
# Iteration 516, loss = 0.26088858
# Iteration 517, loss = 0.26000772
# Iteration 518, loss = 0.25912637
# Iteration 519, loss = 0.25824616
# Iteration 520, loss = 0.25736700
# Iteration 521, loss = 0.25648577
# Iteration 522, loss = 0.25560614
# Iteration 523, loss = 0.25472097
# Iteration 524, loss = 0.25384223
# Iteration 525, loss = 0.25295987
# Iteration 526, loss = 0.25208734
# Iteration 527, loss = 0.25122217
# Iteration 528, loss = 0.25035403
# Iteration 529, loss = 0.24948575
# Iteration 530, loss = 0.24862245
# Iteration 531, loss = 0.24771684
# Iteration 532, loss = 0.24659694
# Iteration 533, loss = 0.24491958
# Iteration 534, loss = 0.24314356
# Iteration 535, loss = 0.24127478
# Iteration 536, loss = 0.23934178
# Iteration 537, loss = 0.23736832
# Iteration 538, loss = 0.23537161
# Iteration 539, loss = 0.23333471
# Iteration 540, loss = 0.23126069
# Iteration 541, loss = 0.22915661
# Iteration 542, loss = 0.22708036
# Iteration 543, loss = 0.22508095
# Iteration 544, loss = 0.22310007
# Iteration 545, loss = 0.22114557
# Iteration 546, loss = 0.21922867
# Iteration 547, loss = 0.21735817
# Iteration 548, loss = 0.21552551
# Iteration 549, loss = 0.21376546
# Iteration 550, loss = 0.21205703
# Iteration 551, loss = 0.21036170
# Iteration 552, loss = 0.20869185
# Iteration 553, loss = 0.20703986
# Iteration 554, loss = 0.20539855
# Iteration 555, loss = 0.20377608
# Iteration 556, loss = 0.20217646
# Iteration 557, loss = 0.20058520
# Iteration 558, loss = 0.19901039
# Iteration 559, loss = 0.19745751
# Iteration 560, loss = 0.19592796
# Iteration 561, loss = 0.19441778
# Iteration 562, loss = 0.19293607
# Iteration 563, loss = 0.19147974
# Iteration 564, loss = 0.19003975
# Iteration 565, loss = 0.18861394
# Iteration 566, loss = 0.18720320
# Iteration 567, loss = 0.18580800
# Iteration 568, loss = 0.18442982
# Iteration 569, loss = 0.18306489
# Iteration 570, loss = 0.18171212
# Iteration 571, loss = 0.18037099
# Iteration 572, loss = 0.17904086
# Iteration 573, loss = 0.17772112
# Iteration 574, loss = 0.17642011
# Iteration 575, loss = 0.17513154
# Iteration 576, loss = 0.17385545
# Iteration 577, loss = 0.17259235
# Iteration 578, loss = 0.17134090
# Iteration 579, loss = 0.17010277
# Iteration 580, loss = 0.16887661
# Iteration 581, loss = 0.16766836
# Iteration 582, loss = 0.16647245
# Iteration 583, loss = 0.16528508
# Iteration 584, loss = 0.16410837
# Iteration 585, loss = 0.16294226
# Iteration 586, loss = 0.16178632
# Iteration 587, loss = 0.16064032
# Iteration 588, loss = 0.15950309
# Iteration 589, loss = 0.15837454
# Iteration 590, loss = 0.15725327
# Iteration 591, loss = 0.15614018
# Iteration 592, loss = 0.15503614
# Iteration 593, loss = 0.15393960
# Iteration 594, loss = 0.15285291
# Iteration 595, loss = 0.15177559
# Iteration 596, loss = 0.15070857
# Iteration 597, loss = 0.14965007
# Iteration 598, loss = 0.14860046
# Iteration 599, loss = 0.14755892
# Iteration 600, loss = 0.14652555
# Iteration 601, loss = 0.14550481
# Iteration 602, loss = 0.14449619
# Iteration 603, loss = 0.14348987
# Iteration 604, loss = 0.14249871
# Iteration 605, loss = 0.14151891
# Iteration 606, loss = 0.14054773
# Iteration 607, loss = 0.13958483
# Iteration 608, loss = 0.13863009
# Iteration 609, loss = 0.13768323
# Iteration 610, loss = 0.13674741
# Iteration 611, loss = 0.13582148
# Iteration 612, loss = 0.13490612
# Iteration 613, loss = 0.13400027
# Iteration 614, loss = 0.13310045
# Iteration 615, loss = 0.13220982
# Iteration 616, loss = 0.13132881
# Iteration 617, loss = 0.13045752
# Iteration 618, loss = 0.12959501
# Iteration 619, loss = 0.12874122
# Iteration 620, loss = 0.12789630
# Iteration 621, loss = 0.12705995
# Iteration 622, loss = 0.12623287
# Iteration 623, loss = 0.12541449
# Iteration 624, loss = 0.12460493
# Iteration 625, loss = 0.12380442
# Iteration 626, loss = 0.12301281
# Iteration 627, loss = 0.12222975
# Iteration 628, loss = 0.12145513
# Iteration 629, loss = 0.12068888
# Iteration 630, loss = 0.11993106
# Iteration 631, loss = 0.11918156
# Iteration 632, loss = 0.11844054
# Iteration 633, loss = 0.11770788
# Iteration 634, loss = 0.11698357
# Iteration 635, loss = 0.11626752
# Iteration 636, loss = 0.11555966
# Iteration 637, loss = 0.11486006
# Iteration 638, loss = 0.11416860
# Iteration 639, loss = 0.11348515
# Iteration 640, loss = 0.11280963
# Iteration 641, loss = 0.11214208
# Iteration 642, loss = 0.11148252
# Iteration 643, loss = 0.11083129
# Iteration 644, loss = 0.11018967
# Iteration 645, loss = 0.10955600
# Iteration 646, loss = 0.10893000
# Iteration 647, loss = 0.10831166
# Iteration 648, loss = 0.10770113
# Iteration 649, loss = 0.10709883
# Iteration 650, loss = 0.10650374
# Iteration 651, loss = 0.10591579
# Iteration 652, loss = 0.10533736
# Iteration 653, loss = 0.10476780
# Iteration 654, loss = 0.10420535
# Iteration 655, loss = 0.10365003
# Iteration 656, loss = 0.10310202
# Iteration 657, loss = 0.10256116
# Iteration 658, loss = 0.10202702
# Iteration 659, loss = 0.10149947
# Iteration 660, loss = 0.10097849
# Iteration 661, loss = 0.10046415
# Iteration 662, loss = 0.09995631
# Iteration 663, loss = 0.09945474
# Iteration 664, loss = 0.09895938
# Iteration 665, loss = 0.09847015
# Iteration 666, loss = 0.09798695
# Iteration 667, loss = 0.09750976
# Iteration 668, loss = 0.09703854
# Iteration 669, loss = 0.09657416
# Iteration 670, loss = 0.09611556
# Iteration 671, loss = 0.09566252
# Iteration 672, loss = 0.09521497
# Iteration 673, loss = 0.09477297
# Iteration 674, loss = 0.09433657
# Iteration 675, loss = 0.09390536
# Iteration 676, loss = 0.09347940
# Iteration 677, loss = 0.09305962
# Iteration 678, loss = 0.09264487
# Iteration 679, loss = 0.09223256
# Iteration 680, loss = 0.09182125
# Iteration 681, loss = 0.09142082
# Iteration 682, loss = 0.09101960
# Iteration 683, loss = 0.09063023
# Iteration 684, loss = 0.09024406
# Iteration 685, loss = 0.08986102
# Iteration 686, loss = 0.08948099
# Iteration 687, loss = 0.08910384
# Iteration 688, loss = 0.08872962
# Iteration 689, loss = 0.08835821
# Iteration 690, loss = 0.08799057
# Iteration 691, loss = 0.08762843
# Iteration 692, loss = 0.08727062
# Iteration 693, loss = 0.08691756
# Iteration 694, loss = 0.08656894
# Iteration 695, loss = 0.08622315
# Iteration 696, loss = 0.08587984
# Iteration 697, loss = 0.08553955
# Iteration 698, loss = 0.08520383
# Iteration 699, loss = 0.08487349
# Iteration 700, loss = 0.08454752
# Iteration 701, loss = 0.08422518
# Iteration 702, loss = 0.08390632
# Iteration 703, loss = 0.08359072
# Iteration 704, loss = 0.08327845
# Iteration 705, loss = 0.08296957
# Iteration 706, loss = 0.08266407
# Iteration 707, loss = 0.08236210
# Iteration 708, loss = 0.08206387
# Iteration 709, loss = 0.08176898
# Iteration 710, loss = 0.08147734
# Iteration 711, loss = 0.08118898
# Iteration 712, loss = 0.08090389
# Iteration 713, loss = 0.08062181
# Iteration 714, loss = 0.08034266
# Iteration 715, loss = 0.08006640
# Iteration 716, loss = 0.07979296
# Iteration 717, loss = 0.07952235
# Iteration 718, loss = 0.07925449
# Iteration 719, loss = 0.07898964
# Iteration 720, loss = 0.07872855
# Iteration 721, loss = 0.07847013
# Iteration 722, loss = 0.07821437
# Iteration 723, loss = 0.07796127
# Iteration 724, loss = 0.07771093
# Iteration 725, loss = 0.07746323
# Iteration 726, loss = 0.07721814
# Iteration 727, loss = 0.07697570
# Iteration 728, loss = 0.07673582
# Iteration 729, loss = 0.07649850
# Iteration 730, loss = 0.07626366
# Iteration 731, loss = 0.07603137
# Iteration 732, loss = 0.07580159
# Iteration 733, loss = 0.07557417
# Iteration 734, loss = 0.07534933
# Iteration 735, loss = 0.07512709
# Iteration 736, loss = 0.07490714
# Iteration 737, loss = 0.07468947
# Iteration 738, loss = 0.07447409
# Iteration 739, loss = 0.07426094
# Iteration 740, loss = 0.07405172
# Iteration 741, loss = 0.07384257
# Iteration 742, loss = 0.07363581
# Iteration 743, loss = 0.07343214
# Iteration 744, loss = 0.07323049
# Iteration 745, loss = 0.07303078
# Iteration 746, loss = 0.07283300
# Iteration 747, loss = 0.07263707
# Iteration 748, loss = 0.07244330
# Iteration 749, loss = 0.07225157
# Iteration 750, loss = 0.07206164
# Iteration 751, loss = 0.07187359
# Iteration 752, loss = 0.07168927
# Iteration 753, loss = 0.07150539
# Iteration 754, loss = 0.07132181
# Iteration 755, loss = 0.07114184
# Iteration 756, loss = 0.07096352
# Iteration 757, loss = 0.07078681
# Iteration 758, loss = 0.07061172
# Iteration 759, loss = 0.07043929
# Iteration 760, loss = 0.07026826
# Iteration 761, loss = 0.07009786
# Iteration 762, loss = 0.06992958
# Iteration 763, loss = 0.06976375
# Iteration 764, loss = 0.06959935
# Iteration 765, loss = 0.06943630
# Iteration 766, loss = 0.06927512
# Iteration 767, loss = 0.06911483
# Iteration 768, loss = 0.06895691
# Iteration 769, loss = 0.06880020
# Iteration 770, loss = 0.06864464
# Iteration 771, loss = 0.06849026
# Iteration 772, loss = 0.06833731
# Iteration 773, loss = 0.06818633
# Iteration 774, loss = 0.06803598
# Iteration 775, loss = 0.06788866
# Iteration 776, loss = 0.06774189
# Iteration 777, loss = 0.06759598
# Iteration 778, loss = 0.06745216
# Iteration 779, loss = 0.06730935
# Iteration 780, loss = 0.06716760
# Iteration 781, loss = 0.06702784
# Iteration 782, loss = 0.06688870
# Iteration 783, loss = 0.06675076
# Iteration 784, loss = 0.06661466
# Iteration 785, loss = 0.06647967
# Iteration 786, loss = 0.06634573
# Iteration 787, loss = 0.06621350
# Iteration 788, loss = 0.06608202
# Iteration 789, loss = 0.06595225
# Iteration 790, loss = 0.06582364
# Iteration 791, loss = 0.06569579
# Iteration 792, loss = 0.06556871
# Iteration 793, loss = 0.06544357
# Iteration 794, loss = 0.06531946
# Iteration 795, loss = 0.06519577
# Iteration 796, loss = 0.06507276
# Iteration 797, loss = 0.06495226
# Iteration 798, loss = 0.06483256
# Iteration 799, loss = 0.06471347
# Iteration 800, loss = 0.06459502
# Iteration 801, loss = 0.06447748
# Iteration 802, loss = 0.06436145
# Iteration 803, loss = 0.06424628
# Iteration 804, loss = 0.06413234
# Iteration 805, loss = 0.06401945
# Iteration 806, loss = 0.06390717
# Iteration 807, loss = 0.06379588
# Iteration 808, loss = 0.06368537
# Iteration 809, loss = 0.06357616
# Iteration 810, loss = 0.06346778
# Iteration 811, loss = 0.06335994
# Iteration 812, loss = 0.06325327
# Iteration 813, loss = 0.06314755
# Iteration 814, loss = 0.06304271
# Iteration 815, loss = 0.06293863
# Iteration 816, loss = 0.06283518
# Iteration 817, loss = 0.06273312
# Iteration 818, loss = 0.06263166
# Iteration 819, loss = 0.06253091
# Iteration 820, loss = 0.06243084
# Iteration 821, loss = 0.06233177
# Iteration 822, loss = 0.06223340
# Iteration 823, loss = 0.06213589
# Iteration 824, loss = 0.06203905
# Iteration 825, loss = 0.06194306
# Iteration 826, loss = 0.06184776
# Iteration 827, loss = 0.06175311
# Iteration 828, loss = 0.06165908
# Iteration 829, loss = 0.06156623
# Iteration 830, loss = 0.06147392
# Iteration 831, loss = 0.06138210
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# /Users/jskaf/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:566: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   X = check_array(X, **check_params)
# 0.9333333333333333

# %%
target_model.predict_proba([['5.1', '3.5', '1.4', '0.2']])
# Out:
# /Users/jskaf/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:566: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   X = check_array(X, **check_params)
# array([[9.99959895e-01, 4.00958878e-05, 9.11335902e-09]])

# %%
def generate_synthetic_data(k_max, c, target_model,columns_mins,columns_maxs, iterations=100, conf_min=0.99, rej_max=1000, k_min = 1):
    j = 0
    x = np.array([np.random.uniform(columns_mins[l], columns_maxs[l]) for l in range(k_max)])
    y_c = 0
    k = k_max
    for i in range(iterations):
        y_class = target_model.predict_proba([x])
        if y_class[0][c] > y_c:
            if y_class[0][c] > conf_min and c == np.argmax(y_class[0]):
                if np.random.uniform(0, 1) <= y_class[0][c]:
                   return x
            x_temp = x
            y_c = y_class[0][c]
            j = 0
        else:
            j += 1
            if j>=rej_max:
                k = max(k_min, k//2)
                j = 0
        indice = np.random.randint(0, 4, size=(1, k))
        for i in indice:
            x[i] = np.random.uniform(columns_mins[i], columns_maxs[i])
    return None

# %%
def generate_shadows_datasets(k_max, c_s, target_model, columns_mins, columns_maxs, mutliple_of_cs, iterations=100, conf_min=0.99, rej_max=1000, k_min = 1, n=10000):
    shadow_datasets = []
    for c in c_s:
        shadow_dataset_c = []
        print(f'Generating {c} label shadow...')
        for j in range(mutliple_of_cs):
            for i in tqdm(range(n)):
                x_k = generate_synthetic_data(k_max, c, target_model, columns_mins, columns_maxs, iterations, conf_min, rej_max, k_min)
                while x_k is None:
                    x_k = generate_synthetic_data(k_max, c, target_model, columns_mins, columns_maxs, iterations, conf_min, rej_max, k_min)
                shadow_dataset_c.append(x_k)
        print(f'{c} label shadow dataset generated\n')
        shadow_datasets.append(shadow_dataset_c)
    return shadow_datasets

# %%
c_s = [0, 1, 2]
mutliple_of_cs = 3
n = 10000

# %%
shadow_datasets = generate_shadows_datasets(4, c_s, target_model, columns_mins, columns_maxs, mutliple_of_cs=mutliple_of_cs, n=n)
# Out:
# Generating 0 label shadow...
# 100%|██████████| 10000/10000 [00:04<00:00, 2354.36it/s]
# 100%|██████████| 10000/10000 [00:04<00:00, 2361.55it/s]
# 100%|██████████| 10000/10000 [00:04<00:00, 2459.04it/s]
# 0 label shadow dataset generated
#
# Generating 1 label shadow...
# 100%|██████████| 10000/10000 [00:04<00:00, 2130.89it/s]
# 100%|██████████| 10000/10000 [00:04<00:00, 2115.03it/s]
# 100%|██████████| 10000/10000 [00:04<00:00, 2131.86it/s]
# 1 label shadow dataset generated
#
# Generating 2 label shadow...
# 100%|██████████| 10000/10000 [00:06<00:00, 1618.75it/s]
# 100%|██████████| 10000/10000 [00:06<00:00, 1550.58it/s]
# 100%|██████████| 10000/10000 [00:06<00:00, 1594.04it/s]
# 2 label shadow dataset generated

# %%
shadow_datasets_train_class_k = []
shadow_datasets_test_class_k = []
shadow_train_labels_class_k = []
shadow_test_labels_class_k = []
for k in c_s:
    temp_train_class_k, temp_test_class_k, temp_train_labels_class_k, temp_test_labels_class_k = train_test_split(shadow_datasets[k], np.full(len(shadow_datasets[k]),c_s[k]), test_size=0.5, shuffle=True)
    shadow_datasets_train_class_k.append(temp_train_class_k)
    shadow_datasets_test_class_k.append(temp_test_class_k)
    shadow_train_labels_class_k.append(temp_train_labels_class_k)
    shadow_test_labels_class_k.append(temp_test_labels_class_k)
shadow_datasets_train_class_k = np.array(shadow_datasets_train_class_k)
shadow_datasets_test_class_k = np.array(shadow_datasets_test_class_k)
shadow_train_labels_class_k = np.array(shadow_train_labels_class_k)
shadow_test_labels_class_k = np.array(shadow_test_labels_class_k)

shadow_test_labels_class_k[1]
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
shadow_dataset_train_k = []
shadow_dataset_test_k = []
shadow_train_labels_k= []
shadow_test_labels_k= []
range_indices_train = len(shadow_datasets_train_class_k[0])//mutliple_of_cs
range_indices_test = len(shadow_datasets_test_class_k[0])//mutliple_of_cs
for k in range(mutliple_of_cs):
    shadow_dataset_train_k.append(np.concatenate([shadow_datasets_train_class_k[i][k*range_indices_train:(k+1)*range_indices_train] for i in range(len(c_s))]))
    shadow_dataset_test_k.append(np.concatenate([shadow_datasets_test_class_k[i][k*range_indices_test:(k+1)*range_indices_test] for i in range(len(c_s))]))
    shadow_train_labels_k.append(np.concatenate([shadow_train_labels_class_k[i][k*range_indices_train:(k+1)*range_indices_train] for i in range(len(c_s))]))
    shadow_test_labels_k.append(np.concatenate([shadow_test_labels_class_k[i][k*range_indices_test:(k+1)*range_indices_test] for i in range(len(c_s))]))
    shadow_dataset_train_k[k], shadow_train_labels_k[k] = shuffle(shadow_dataset_train_k[k], shadow_train_labels_k[k])

shadow_train_labels_k
# Out:
# [array([0, 1, 0, ..., 0, 1, 2]),
#  array([1, 2, 0, ..., 0, 1, 0]),
#  array([0, 0, 1, ..., 2, 0, 1])]

# %%
shadow_models = []
for k in range(mutliple_of_cs):
    print(f'Shadow model {k} training...')
    shadow_model_k = MLPClassifier(hidden_layer_sizes=(20,10), max_iter=1000).fit(shadow_dataset_train_k[k], shadow_train_labels_k[k])
    print(f'Shadow model {k} accuracy: {shadow_model_k.score(shadow_dataset_test_k[k], shadow_test_labels_k[k])}\n')
    shadow_models.append(shadow_model_k)
# Out:
# Shadow model 0 training...
# Shadow model 0 accuracy: 1.0
#
# Shadow model 1 training...
# Shadow model 1 accuracy: 1.0
#
# Shadow model 2 training...
# Shadow model 2 accuracy: 1.0

# %%
def attack_training_set_in(shadow_training_dataset, shadow_train_labels_k, target_shadow_model):
    attack_dataset = []
    attack_labels = []
    print(f'Generating attack dataset in...')
    for k in range(len(shadow_training_dataset)):
        y = target_shadow_model.predict_proba([shadow_training_dataset[k]])
        attack_dataset.append([y[0], shadow_train_labels_k[k]])
        attack_labels.append(1)
    return attack_dataset, attack_labels

# %%
def attack_training_set_out(shadow_test_dataset, shadow_test_labels_k ,target_shadow_model):
    attack_dataset = []
    attack_labels = []
    print(f'Generating attack dataset out...')
    for k in range(len(shadow_test_dataset)):
        y = target_shadow_model.predict_proba([shadow_test_dataset[k]])
        attack_dataset.append([y[0], shadow_test_labels_k[k]])
        attack_labels.append(0)
    return attack_dataset, attack_labels

# %%
attack_dataset = []
attack_labels = []
for k in range(mutliple_of_cs):
    attack_dataset_in, attack_labels_in = attack_training_set_in(shadow_dataset_train_k[k], shadow_train_labels_k[k], shadow_models[k])
    attack_dataset_out, attack_labels_out = attack_training_set_out(shadow_dataset_test_k[k], shadow_test_labels_k[k], shadow_models[k])
    attack_dataset += attack_dataset_in
    attack_dataset += attack_dataset_out
    attack_labels += attack_labels_in
    attack_labels += attack_labels_out
attack_labels = np.array(attack_labels)
df = pd.DataFrame(data=attack_dataset, columns=['y', 'class'])
print(len(attack_labels))
# Out:
# Generating attack dataset in...
# Generating attack dataset out...
# Generating attack dataset in...
# Generating attack dataset out...
# Generating attack dataset in...
# Generating attack dataset out...
# 90000

# %%
attack_dataset = []
attack_models = []
for c in c_s:
    dataset = df[df['class'] == c]['y']
    labels = attack_labels[df['class'] == c]
    dataset = np.array([x for x in dataset])
    train_dataset, test_dataset, train_labels, test_labels = train_test_split(dataset, labels, test_size=0.1, shuffle=True)
    print(sum(train_labels == 1))
    print(f'Attack model {c} training...')
    # attack_model = MLPClassifier(hidden_layer_sizes=(80, 80, 80, 80,40, 40, 40), max_iter=1000).fit(train_dataset, train_labels)
    attack_model = RandomForestClassifier(n_estimators=1000).fit(train_dataset, train_labels)
    y_pred = attack_model.predict(test_dataset)
    print(f'Attack model {c} accuracy: {attack_model.score(test_dataset, test_labels)}')
    print(f'Attack model {c} recall: {recall_score(test_labels, y_pred)}')
    print(f'Attack model {c} precision: {precision_score(test_labels, y_pred)}')
    print(f'Attack model {c} f1: {f1_score(test_labels, y_pred)}\n')
    attack_models.append(attack_model)
# Out:
# 13494
# Attack model 0 training...
# Attack model 0 accuracy: 0.49466666666666664
# Attack model 0 recall: 0.897742363877822
# Attack model 0 precision: 0.49815770081061167
# Attack model 0 f1: 0.6407582938388626
#
# 13465
# Attack model 1 training...
# Attack model 1 accuracy: 0.491
# Attack model 1 recall: 0.24560260586319219
# Attack model 1 precision: 0.5053619302949062
# Attack model 1 f1: 0.3305567733450241
#
# 13486
# Attack model 2 training...
# Attack model 2 accuracy: 0.503
# Attack model 2 recall: 0.42668428005284015
# Attack model 2 precision: 0.5090622537431048
# Attack model 2 f1: 0.46424721523535745

# %%
In_samples_y_0 = target_model.predict_proba(train[np.where(train_dataset_target_model_labels == 0)])
In_samples_y_1 = target_model.predict_proba(train[np.where(train_dataset_target_model_labels == 1)])
In_samples_y_2 = target_model.predict_proba(train[np.where(train_dataset_target_model_labels == 2)])

Out_samples_y_0 = target_model.predict_proba(test[np.where(test_dataset_target_model_labels == 0)])
Out_samples_y_1 = target_model.predict_proba(test[np.where(test_dataset_target_model_labels == 1)])
Out_samples_y_2 = target_model.predict_proba(test[np.where(test_dataset_target_model_labels == 2)])

labels_in_0 = np.full(len(In_samples_y_0), 1)
labels_in_1 = np.full(len(In_samples_y_1), 1)
labels_in_2 = np.full(len(In_samples_y_2), 1)

labels_out_0 = np.full(len(Out_samples_y_0), 0)
labels_out_1 = np.full(len(Out_samples_y_1), 0)
labels_out_2 = np.full(len(Out_samples_y_2), 0)

evaluation_0 = np.concatenate((In_samples_y_0, Out_samples_y_0))
evaluation_1 = np.concatenate((In_samples_y_1, Out_samples_y_1))
evaluation_2 = np.concatenate((In_samples_y_2, Out_samples_y_2))

labels_0 = np.concatenate((labels_in_0, labels_out_0))
labels_1 = np.concatenate((labels_in_1, labels_out_1))
labels_2 = np.concatenate((labels_in_2, labels_out_2))

y_pred_0 = attack_models[0].predict(evaluation_0)
y_pred_1 = attack_models[1].predict(evaluation_1)
y_pred_2 = attack_models[2].predict(evaluation_2)

print(f'Attack model accuracy on class 0: {accuracy_score(labels_0, y_pred_0)}')
print(f'Attack model recall on class 0: {recall_score(labels_0, y_pred_0)}')
print(f'Attack model precision on class 0: {precision_score(labels_0, y_pred_0)}')
print(f'Attack model f1 on class 0: {f1_score(labels_0, y_pred_0)}\n')

print(f'Attack model accuracy on class 1: {accuracy_score(labels_1, y_pred_1)}')
print(f'Attack model recall on class 1: {recall_score(labels_1, y_pred_1)}')
print(f'Attack model precision on class 1: {precision_score(labels_1, y_pred_1)}')
print(f'Attack model f1 on class 1: {f1_score(labels_1, y_pred_1)}\n')

print(f'Attack model accuracy on class 2: {accuracy_score(labels_2, y_pred_2)}')
print(f'Attack model recall on class 2: {recall_score(labels_2, y_pred_2)}')
print(f'Attack model precision on class 2: {precision_score(labels_2, y_pred_2)}')
print(f'Attack model f1 on class 2: {f1_score(labels_2, y_pred_2)}\n')
# Out:
# Attack model accuracy on class 0: 0.46
# Attack model recall on class 0: 0.4772727272727273
# Attack model precision on class 0: 0.84
# Attack model f1 on class 0: 0.6086956521739131
#
# Attack model accuracy on class 1: 0.76
# Attack model recall on class 1: 0.9743589743589743
# Attack model precision on class 1: 0.7755102040816326
# Attack model f1 on class 1: 0.8636363636363635
#
# Attack model accuracy on class 2: 0.6
# Attack model recall on class 2: 0.6756756756756757
# Attack model precision on class 2: 0.7575757575757576
# Attack model f1 on class 2: 0.7142857142857142
# /Users/jskaf/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:566: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   X = check_array(X, **check_params)
# /Users/jskaf/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:566: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   X = check_array(X, **check_params)
# /Users/jskaf/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:566: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   X = check_array(X, **check_params)
# /Users/jskaf/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:566: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   X = check_array(X, **check_params)
# /Users/jskaf/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:566: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   X = check_array(X, **check_params)
# /Users/jskaf/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:566: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   X = check_array(X, **check_params)

# %%
new_target_model = MLPClassifier(hidden_layer_sizes=(20,10), max_iter=50, verbose=True).fit(train, train_dataset_target_model_labels)
new_target_model.score(test, test_dataset_target_model_labels)
# Out:
# Iteration 1, loss = 1.06395077
# Iteration 2, loss = 1.04768828
# Iteration 3, loss = 1.03208214
# Iteration 4, loss = 1.01705012
# Iteration 5, loss = 1.00262801
# Iteration 6, loss = 0.98879970
# Iteration 7, loss = 0.97555023
# Iteration 8, loss = 0.96294728
# Iteration 9, loss = 0.95094137
# Iteration 10, loss = 0.93955790
# Iteration 11, loss = 0.92883403
# Iteration 12, loss = 0.91880556
# Iteration 13, loss = 0.90933820
# Iteration 14, loss = 0.90038612
# Iteration 15, loss = 0.89189427
# Iteration 16, loss = 0.88384151
# Iteration 17, loss = 0.87619368
# Iteration 18, loss = 0.86884724
# Iteration 19, loss = 0.86190531
# Iteration 20, loss = 0.85537074
# Iteration 21, loss = 0.84924177
# Iteration 22, loss = 0.84321762
# Iteration 23, loss = 0.83724032
# Iteration 24, loss = 0.83123750
# Iteration 25, loss = 0.82518365
# Iteration 26, loss = 0.81907322
# Iteration 27, loss = 0.81293177
# Iteration 28, loss = 0.80680560
# Iteration 29, loss = 0.80066230
# Iteration 30, loss = 0.79451207
# Iteration 31, loss = 0.78844731
# Iteration 32, loss = 0.78241365
# Iteration 33, loss = 0.77646271
# Iteration 34, loss = 0.77070873
# Iteration 35, loss = 0.76511396
# Iteration 36, loss = 0.75964538
# Iteration 37, loss = 0.75432431
# Iteration 38, loss = 0.74912050
# Iteration 39, loss = 0.74407027
# Iteration 40, loss = 0.73913732
# Iteration 41, loss = 0.73419189
# Iteration 42, loss = 0.72915699
# Iteration 43, loss = 0.72404163
# Iteration 44, loss = 0.71884349
# Iteration 45, loss = 0.71358489
# Iteration 46, loss = 0.70830552
# Iteration 47, loss = 0.70301774
# Iteration 48, loss = 0.69775631
# Iteration 49, loss = 0.69253859
# Iteration 50, loss = 0.68737254
# /Users/jskaf/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jskaf/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:566: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   X = check_array(X, **check_params)
# 0.5666666666666667

# %%
In_samples_y_0 = new_target_model.predict_proba(train[np.where(train_dataset_target_model_labels == 0)])
In_samples_y_1 = new_target_model.predict_proba(train[np.where(train_dataset_target_model_labels == 1)])
In_samples_y_2 = new_target_model.predict_proba(train[np.where(train_dataset_target_model_labels == 2)])

Out_samples_y_0 = new_target_model.predict_proba(test[np.where(test_dataset_target_model_labels == 0)])
Out_samples_y_1 = new_target_model.predict_proba(test[np.where(test_dataset_target_model_labels == 1)])
Out_samples_y_2 = new_target_model.predict_proba(test[np.where(test_dataset_target_model_labels == 2)])

labels_in_0 = np.full(len(In_samples_y_0), 1)
labels_in_1 = np.full(len(In_samples_y_1), 1)
labels_in_2 = np.full(len(In_samples_y_2), 1)

labels_out_0 = np.full(len(Out_samples_y_0), 0)
labels_out_1 = np.full(len(Out_samples_y_1), 0)
labels_out_2 = np.full(len(Out_samples_y_2), 0)

evaluation_0 = np.concatenate((In_samples_y_0, Out_samples_y_0))
evaluation_1 = np.concatenate((In_samples_y_1, Out_samples_y_1))
evaluation_2 = np.concatenate((In_samples_y_2, Out_samples_y_2))

labels_0 = np.concatenate((labels_in_0, labels_out_0))
labels_1 = np.concatenate((labels_in_1, labels_out_1))
labels_2 = np.concatenate((labels_in_2, labels_out_2))

y_pred_0 = attack_models[0].predict(evaluation_0)
y_pred_1 = attack_models[1].predict(evaluation_1)
y_pred_2 = attack_models[2].predict(evaluation_2)

print(f'Attack model accuracy on class 0: {accuracy_score(labels_0, y_pred_0)}')
print(f'Attack model recall on class 0: {recall_score(labels_0, y_pred_0)}')
print(f'Attack model precision on class 0: {precision_score(labels_0, y_pred_0)}')
print(f'Attack model f1 on class 0: {f1_score(labels_0, y_pred_0)}\n')

print(f'Attack model accuracy on class 1: {accuracy_score(labels_1, y_pred_1)}')
print(f'Attack model recall on class 1: {recall_score(labels_1, y_pred_1)}')
print(f'Attack model precision on class 1: {precision_score(labels_1, y_pred_1)}')
print(f'Attack model f1 on class 1: {f1_score(labels_1, y_pred_1)}\n')

print(f'Attack model accuracy on class 2: {accuracy_score(labels_2, y_pred_2)}')
print(f'Attack model recall on class 2: {recall_score(labels_2, y_pred_2)}')
print(f'Attack model precision on class 2: {precision_score(labels_2, y_pred_2)}')
print(f'Attack model f1 on class 2: {f1_score(labels_2, y_pred_2)}\n')
# Out:
# /Users/jskaf/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:566: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   X = check_array(X, **check_params)
# /Users/jskaf/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:566: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   X = check_array(X, **check_params)
# /Users/jskaf/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:566: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   X = check_array(X, **check_params)
# /Users/jskaf/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:566: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   X = check_array(X, **check_params)
# /Users/jskaf/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:566: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   X = check_array(X, **check_params)
# /Users/jskaf/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:566: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   X = check_array(X, **check_params)
# Attack model accuracy on class 0: 0.88
# Attack model recall on class 0: 1.0
# Attack model precision on class 0: 0.88
# Attack model f1 on class 0: 0.9361702127659575
#
# Attack model accuracy on class 1: 0.78
# Attack model recall on class 1: 1.0
# Attack model precision on class 1: 0.78
# Attack model f1 on class 1: 0.8764044943820225
#
# Attack model accuracy on class 2: 0.74
# Attack model recall on class 2: 1.0
# Attack model precision on class 2: 0.74
# Attack model f1 on class 2: 0.8505747126436781
